# %% [markdown]
# ## Enron
# Create a synthetic graph from the Enron email network and compare the  metrics between the original graph and synthetic graph for intrinsic validation.

# %%
# import modules
import os
os.chdir('..')
print(os.getcwd())

import pickle
from tigger_package.orchestrator import Orchestrator
from tigger_package.tools import plot_adj_matrix
import networkx as nx 
import time
# Out:
# /Users/tonpoppe/workspace/tigger_adj_rep/tigger_adj
# loaded
# loaded

# %% [markdown]
# ## GRAPHSAGE hyperparam

# %%
# train graphsage
enron_folder = "data/enron/"
orchestrator = Orchestrator(enron_folder)
grid_res = orchestrator.lin_grid_search_graphsage({"learning_rate": [0.0001, 0.00001,0.000001]})
# Out:
# creating neighbors dicts
#   0%|          | 0/2689 [00:00<?, ?it/s]
# number of features 5
# number of nodes, 149
# device is mps
# create edge list
#   0%|          | 0/149 [00:00<?, ?it/s]
# shuffling
# Epoch: 7980, loss: 1.357661574274971e-07, elapsed time 0.09, remaining time: 1.84664Saving to ,  data/enron/embed/model//graphsage0.pth
#
#  Start boosting
# boost iter:0
# Epoch: 1980, loss: 6.622739245898401e-09, elapsed time 0.06, remaining time: 1.144660573.1Saving to ,  data/enron/embed/model//graphsage0_0.pth
# boost iter:1
# Epoch: 1980, loss: 3.3113696229492007e-09, elapsed time 0.07, remaining time: 1.423Saving to ,  data/enron/embed/model//graphsage0_1.pth
# duration 645.856246 sec
# Saving to ,  data/enron/embed/model//model_final
# calculating and saving embeddings to data/enron/embed/model//embedding_matrix_final
# /Users/tonpoppe/anaconda3/envs/tigger/lib/python3.11/site-packages/pandas/io/parquet.py:189: UserWarning: The DataFrame has column names of mixed type. They will be converted to strings and not roundtrip correctly.
#   table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
# creating neighbors dicts
#   0%|          | 0/2689 [00:00<?, ?it/s]
# number of features 5
# number of nodes, 149
# device is mps
# create edge list
#   0%|          | 0/149 [00:00<?, ?it/s]
# shuffling
# Epoch: 7980, loss: 0.0014417603379115462, elapsed time 0.08, remaining time: 1.520Saving to ,  data/enron/embed/model//graphsage0.pth
#
#  Start boosting
# boost iter:0
# Epoch: 1980, loss: 0.00019988432177342474, elapsed time 0.06, remaining time: 1.369Saving to ,  data/enron/embed/model//graphsage0_0.pth
# boost iter:1
# Epoch: 1980, loss: 6.085487984819338e-05, elapsed time 0.08, remaining time: 1.504Saving to ,  data/enron/embed/model//graphsage0_1.pth
# duration 627.836996 sec
# Saving to ,  data/enron/embed/model//model_final
# calculating and saving embeddings to data/enron/embed/model//embedding_matrix_final
# /Users/tonpoppe/anaconda3/envs/tigger/lib/python3.11/site-packages/pandas/io/parquet.py:189: UserWarning: The DataFrame has column names of mixed type. They will be converted to strings and not roundtrip correctly.
#   table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
# creating neighbors dicts
#   0%|          | 0/2689 [00:00<?, ?it/s]
# number of features 5
# number of nodes, 149
# device is mps
# create edge list
#   0%|          | 0/149 [00:00<?, ?it/s]
# shuffling
# Epoch: 7980, loss: 0.6955425143241882, elapsed time 0.11, remaining time: 2.2478Saving to ,  data/enron/embed/model//graphsage0.pth
#
#  Start boosting
# boost iter:0
# Epoch: 1980, loss: 0.6807549595832825, elapsed time 0.07, remaining time: 1.530Saving to ,  data/enron/embed/model//graphsage0_0.pth
# boost iter:1
# Epoch: 1980, loss: 0.6682402491569519, elapsed time 0.07, remaining time: 1.54Saving to ,  data/enron/embed/model//graphsage0_1.pth
# duration 696.443213 sec
# Saving to ,  data/enron/embed/model//model_final
# calculating and saving embeddings to data/enron/embed/model//embedding_matrix_final
# /Users/tonpoppe/anaconda3/envs/tigger/lib/python3.11/site-packages/pandas/io/parquet.py:189: UserWarning: The DataFrame has column names of mixed type. They will be converted to strings and not roundtrip correctly.
#   table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
# loss: [3.642506651857502e-09, 6.430621069739573e-05, 0.6681749284267425]
# val loss: [49.53301315307617, 4.706233263015747, 0.6937384486198426]

# %%
# sleected learning rate = 0.000001
grid_res['config'] = orchestrator.config
import pickle
res_filename = 'data/enron/exp_results/graphcase_gridsear_learningrate1.pickle'
pickle.dump(grid_res, open(res_filename, 'wb'))

# %%
# train graphsage
enron_folder = "data/enron/"
orchestrator = Orchestrator(enron_folder)
grid_res = orchestrator.lin_grid_search_graphsage({"dropout": [0.1, 0.2, 0.3]})
# Out:
# creating neighbors dicts
#   0%|          | 0/2689 [00:00<?, ?it/s]
# number of features 5
# number of nodes, 149
# device is mps
# create edge list
#   0%|          | 0/149 [00:00<?, ?it/s]
# shuffling
# Epoch: 7980, loss: 0.6208967566490173, elapsed time 0.07, remaining time: 1.4788Saving to ,  data/enron/embed/model//graphsage0.pth
#
#  Start boosting
# boost iter:0
# Epoch: 1980, loss: 0.6119279265403748, elapsed time 0.06, remaining time: 1.33Saving to ,  data/enron/embed/model//graphsage0_0.pth
# boost iter:1
# Epoch: 1980, loss: 0.5986983180046082, elapsed time 0.06, remaining time: 1.301Saving to ,  data/enron/embed/model//graphsage0_1.pth
# duration 655.537418 sec
# Saving to ,  data/enron/embed/model//model_final
# calculating and saving embeddings to data/enron/embed/model//embedding_matrix_final
# /Users/tonpoppe/anaconda3/envs/tigger/lib/python3.11/site-packages/pandas/io/parquet.py:189: UserWarning: The DataFrame has column names of mixed type. They will be converted to strings and not roundtrip correctly.
#   table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
# creating neighbors dicts
#   0%|          | 0/2689 [00:00<?, ?it/s]
# number of features 5
# number of nodes, 149
# device is mps
# create edge list
#   0%|          | 0/149 [00:00<?, ?it/s]
# shuffling
# Epoch: 7980, loss: 0.6489887237548828, elapsed time 0.06, remaining time: 1.250Saving to ,  data/enron/embed/model//graphsage0.pth
#
#  Start boosting
# boost iter:0
# Epoch: 1980, loss: 0.6406977772712708, elapsed time 0.06, remaining time: 1.34Saving to ,  data/enron/embed/model//graphsage0_0.pth
# boost iter:1
# Epoch: 1980, loss: 0.630290150642395, elapsed time 0.09, remaining time: 1.965Saving to ,  data/enron/embed/model//graphsage0_1.pth
# duration 588.183683 sec
# Saving to ,  data/enron/embed/model//model_final
# calculating and saving embeddings to data/enron/embed/model//embedding_matrix_final
# /Users/tonpoppe/anaconda3/envs/tigger/lib/python3.11/site-packages/pandas/io/parquet.py:189: UserWarning: The DataFrame has column names of mixed type. They will be converted to strings and not roundtrip correctly.
#   table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
# creating neighbors dicts
#   0%|          | 0/2689 [00:00<?, ?it/s]
# number of features 5
# number of nodes, 149
# device is mps
# create edge list
#   0%|          | 0/149 [00:00<?, ?it/s]
# shuffling
# Epoch: 7980, loss: 0.6803147196769714, elapsed time 0.10, remaining time: 1.9353Saving to ,  data/enron/embed/model//graphsage0.pth
#
#  Start boosting
# boost iter:0
# Epoch: 1980, loss: 0.6689820289611816, elapsed time 0.11, remaining time: 2.109Saving to ,  data/enron/embed/model//graphsage0_0.pth
# boost iter:1
# Epoch: 1980, loss: 0.6545213460922241, elapsed time 0.08, remaining time: 1.693Saving to ,  data/enron/embed/model//graphsage0_1.pth
# duration 791.636578 sec
# Saving to ,  data/enron/embed/model//model_final
# calculating and saving embeddings to data/enron/embed/model//embedding_matrix_final
# /Users/tonpoppe/anaconda3/envs/tigger/lib/python3.11/site-packages/pandas/io/parquet.py:189: UserWarning: The DataFrame has column names of mixed type. They will be converted to strings and not roundtrip correctly.
#   table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
# loss: [0.5997628927230835, 0.6316456079483033, 0.6570502460002899]
# val loss: [0.6978703141212463, 0.6949561178684235, 0.6941163897514343]

# %%
# selected dropout = 0.3
grid_res['config'] = orchestrator.config
import pickle
res_filename = 'data/enron/exp_results/graphcase_gridsearch_dropout1.pickle'
pickle.dump(grid_res, open(res_filename, 'wb'))

# %%
# final run with more epochs and two learning rates

# train graphsage
enron_folder = "data/enron/"
orchestrator = Orchestrator(enron_folder)
grid_res = orchestrator.lin_grid_search_graphsage({"learning_rate": [0.000001, 0.0000001]})
# Out:
# creating neighbors dicts
#   0%|          | 0/2689 [00:00<?, ?it/s]
# number of features 5
# number of nodes, 149
# device is mps
# create edge list
#   0%|          | 0/149 [00:00<?, ?it/s]
# shuffling
# Epoch: 19980, loss: 0.5268624424934387, elapsed time 0.10, remaining time: 2.1161Saving to ,  data/enron/embed/model//graphsage0.pth
#
#  Start boosting
# boost iter:0
# Epoch: 7980, loss: 0.3737160265445709, elapsed time 0.06, remaining time: 1.2809Saving to ,  data/enron/embed/model//graphsage0_0.pth
# boost iter:1
# Epoch: 7980, loss: 0.18555782735347748, elapsed time 0.06, remaining time: 1.2960Saving to ,  data/enron/embed/model//graphsage0_1.pth
# duration 2520.663437 sec
# Saving to ,  data/enron/embed/model//model_final
# calculating and saving embeddings to data/enron/embed/model//embedding_matrix_final
# /Users/tonpoppe/anaconda3/envs/tigger/lib/python3.11/site-packages/pandas/io/parquet.py:189: UserWarning: The DataFrame has column names of mixed type. They will be converted to strings and not roundtrip correctly.
#   table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
# creating neighbors dicts
#   0%|          | 0/2689 [00:00<?, ?it/s]
# number of features 5
# number of nodes, 149
# device is mps
# create edge list
#   0%|          | 0/149 [00:00<?, ?it/s]
# shuffling
# Epoch: 19980, loss: 0.6556852459907532, elapsed time 0.06, remaining time: 1.2777Saving to ,  data/enron/embed/model//graphsage0.pth
#
#  Start boosting
# boost iter:0
# Epoch: 7980, loss: 0.6529191136360168, elapsed time 0.08, remaining time: 1.563Saving to ,  data/enron/embed/model//graphsage0_0.pth
# boost iter:1
# Epoch: 7980, loss: 0.6499921083450317, elapsed time 0.06, remaining time: 1.2011Saving to ,  data/enron/embed/model//graphsage0_1.pth
# duration 1705.816735 sec
# Saving to ,  data/enron/embed/model//model_final
# calculating and saving embeddings to data/enron/embed/model//embedding_matrix_final
# /Users/tonpoppe/anaconda3/envs/tigger/lib/python3.11/site-packages/pandas/io/parquet.py:189: UserWarning: The DataFrame has column names of mixed type. They will be converted to strings and not roundtrip correctly.
#   table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
# loss: [0.19476600140333175, 0.650073230266571]
# val loss: [0.9518462419509888, 0.6940869688987732]

# %%
# selected ....
grid_res['config'] = orchestrator.config
import pickle
res_filename = 'data/enron/exp_results/graphcase_gridsearch_learning_Rate2.pickle'
pickle.dump(grid_res, open(res_filename, 'wb'))

# %% [markdown]
# ## Train final graphsage embedding

# %%
enron_folder = "data/enron/"
orchestrator = Orchestrator(enron_folder)
train_metrics = orchestrator.create_embedding()
# Out:
# creating neighbors dicts
#   0%|          | 0/2689 [00:00<?, ?it/s]
# number of features 5
# number of nodes, 149
# device is cpu
# create edge list
#   0%|          | 0/149 [00:00<?, ?it/s]
# shuffling
# Epoch: 2980, loss: 1.8669677956495434e-05, elapsed time 0.00, remaining time: 0.1Saving to ,  data/enron/embed/model//graphsage0.pth
#
#  Start boosting
# boost iter:0
# Epoch: 1480, loss: 5.510133178177057e-06, elapsed time 0.00, remaining time: 0.1Saving to ,  data/enron/embed/model//graphsage0_0.pth
# boost iter:1
# Epoch: 1480, loss: 2.2417996206058888e-06, elapsed time 0.00, remaining time: 0.1Saving to ,  data/enron/embed/model//graphsage0_1.pth
# duration 18.519036 sec
# Saving to ,  data/enron/embed/model//model_final
# calculating and saving embeddings to data/enron/embed/model//embedding_matrix_final
# /Users/tonpoppe/anaconda3/envs/tigger/lib/python3.11/site-packages/pandas/io/parquet.py:189: UserWarning: The DataFrame has column names of mixed type. They will be converted to strings and not roundtrip correctly.
#   table = self.api.Table.from_pandas(df, **from_pandas_kwargs)

# %%
# save results
import pickle
train_config = orchestrator.config.copy()
train_config['metrcis'] = train_metrics
res_filename = 'data/enron/exp_results/graphcase_final_run_metrics.pickle'
pickle.dump(train_config, open(res_filename, 'wb'))

# %%
# convert final embedding to csv for tensorflow embedding viewer
import pandas as pd
embed = pd.read_parquet("data/enron/embed/embedding.parquet")
embed.to_parquet("data/enron/embed/embedding_final.parquet")
embed.to_csv("data/enron/embed/embedding_final.csv", sep='\t', header=False, index=False, )
embed.hist(figsize=(20,20), bins=20)
# Out:
# array([[<Axes: title={'center': 'id'}>, <Axes: title={'center': '0'}>,
#         <Axes: title={'center': '1'}>, <Axes: title={'center': '2'}>,
#         <Axes: title={'center': '3'}>, <Axes: title={'center': '4'}>,
#         <Axes: title={'center': '5'}>, <Axes: title={'center': '6'}>,
#         <Axes: title={'center': '7'}>, <Axes: title={'center': '8'}>,
#         <Axes: title={'center': '9'}>],
#        [<Axes: title={'center': '10'}>, <Axes: title={'center': '11'}>,
#         <Axes: title={'center': '12'}>, <Axes: title={'center': '13'}>,
#         <Axes: title={'center': '14'}>, <Axes: title={'center': '15'}>,
#         <Axes: title={'center': '16'}>, <Axes: title={'center': '17'}>,
#         <Axes: title={'center': '18'}>, <Axes: title={'center': '19'}>,
#         <Axes: title={'center': '20'}>],
#        [<Axes: title={'center': '21'}>, <Axes: title={'center': '22'}>,
#         <Axes: title={'center': '23'}>, <Axes: title={'center': '24'}>,
#         <Axes: title={'center': '25'}>, <Axes: title={'center': '26'}>,
#         <Axes: title={'center': '27'}>, <Axes: title={'center': '28'}>,
#         <Axes: title={'center': '29'}>, <Axes: title={'center': '30'}>,
#         <Axes: title={'center': '31'}>],
#        [<Axes: title={'center': '32'}>, <Axes: title={'center': '33'}>,
#         <Axes: title={'center': '34'}>, <Axes: title={'center': '35'}>,
#         <Axes: title={'center': '36'}>, <Axes: title={'center': '37'}>,
#         <Axes: title={'center': '38'}>, <Axes: title={'center': '39'}>,
#         <Axes: title={'center': '40'}>, <Axes: title={'center': '41'}>,
#         <Axes: title={'center': '42'}>],
#        [<Axes: title={'center': '43'}>, <Axes: title={'center': '44'}>,
#         <Axes: title={'center': '45'}>, <Axes: title={'center': '46'}>,
#         <Axes: title={'center': '47'}>, <Axes: title={'center': '48'}>,
#         <Axes: title={'center': '49'}>, <Axes: title={'center': '50'}>,
#         <Axes: title={'center': '51'}>, <Axes: title={'center': '52'}>,
#         <Axes: title={'center': '53'}>],
#        [<Axes: title={'center': '54'}>, <Axes: title={'center': '55'}>,
#         <Axes: title={'center': '56'}>, <Axes: title={'center': '57'}>,
#         <Axes: title={'center': '58'}>, <Axes: title={'center': '59'}>,
#         <Axes: title={'center': '60'}>, <Axes: title={'center': '61'}>,
#         <Axes: title={'center': '62'}>, <Axes: title={'center': '63'}>,
#         <Axes: title={'center': '64'}>],
#        [<Axes: title={'center': '65'}>, <Axes: title={'center': '66'}>,
#         <Axes: title={'center': '67'}>, <Axes: title={'center': '68'}>,
#         <Axes: title={'center': '69'}>, <Axes: title={'center': '70'}>,
#         <Axes: title={'center': '71'}>, <Axes: title={'center': '72'}>,
#         <Axes: title={'center': '73'}>, <Axes: title={'center': '74'}>,
#         <Axes: title={'center': '75'}>],
#        [<Axes: title={'center': '76'}>, <Axes: title={'center': '77'}>,
#         <Axes: title={'center': '78'}>, <Axes: title={'center': '79'}>,
#         <Axes: title={'center': '80'}>, <Axes: title={'center': '81'}>,
#         <Axes: title={'center': '82'}>, <Axes: title={'center': '83'}>,
#         <Axes: title={'center': '84'}>, <Axes: title={'center': '85'}>,
#         <Axes: title={'center': '86'}>],
#        [<Axes: title={'center': '87'}>, <Axes: title={'center': '88'}>,
#         <Axes: title={'center': '89'}>, <Axes: title={'center': '90'}>,
#         <Axes: title={'center': '91'}>, <Axes: title={'center': '92'}>,
#         <Axes: title={'center': '93'}>, <Axes: title={'center': '94'}>,
#         <Axes: title={'center': '95'}>, <Axes: title={'center': '96'}>,
#         <Axes: title={'center': '97'}>],
#        [<Axes: title={'center': '98'}>, <Axes: title={'center': '99'}>,
#         <Axes: title={'center': '100'}>, <Axes: title={'center': '101'}>,
#         <Axes: title={'center': '102'}>, <Axes: title={'center': '103'}>,
#         <Axes: title={'center': '104'}>, <Axes: title={'center': '105'}>,
#         <Axes: title={'center': '106'}>, <Axes: title={'center': '107'}>,
#         <Axes: title={'center': '108'}>],
#        [<Axes: title={'center': '109'}>, <Axes: title={'center': '110'}>,
#         <Axes: title={'center': '111'}>, <Axes: title={'center': '112'}>,
#         <Axes: title={'center': '113'}>, <Axes: title={'center': '114'}>,
#         <Axes: title={'center': '115'}>, <Axes: title={'center': '116'}>,
#         <Axes: title={'center': '117'}>, <Axes: title={'center': '118'}>,
#         <Axes: title={'center': '119'}>],
#        [<Axes: title={'center': '120'}>, <Axes: title={'center': '121'}>,
#         <Axes: title={'center': '122'}>, <Axes: title={'center': '123'}>,
#         <Axes: title={'center': '124'}>, <Axes: title={'center': '125'}>,
#         <Axes: title={'center': '126'}>, <Axes: title={'center': '127'}>,
#         <Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %% [markdown]
# ## flownet training

# %%
enron_folder = "data/enron/"
orchestrator = Orchestrator(enron_folder)
start = time.time()
res = orchestrator.lin_grid_search_flownet({"learning_rate": [0.001, 0.0001, 0.00001]})
end = time.time()
print(f"Duration: {end-start}")
# Out:
# /Users/tonpoppe/workspace/tigger_adj_rep/tigger_adj/tigger_package/flownet.py:121: UserWarning: not all nodes are included! are there nodes without edges?
#   warnings.warn("not all nodes are included! are there nodes without edges?")
# Epoch 1981/2000  ['loss:-94.45130920410156', 'val_loss:157.85470581054688']
# /Users/tonpoppe/workspace/tigger_adj_rep/tigger_adj/tigger_package/flownet.py:121: UserWarning: not all nodes are included! are there nodes without edges?
#   warnings.warn("not all nodes are included! are there nodes without edges?")
# Epoch 1981/2000  ['loss:-72.00664520263672', 'val_loss:-22.38692283630371']]]
# /Users/tonpoppe/workspace/tigger_adj_rep/tigger_adj/tigger_package/flownet.py:121: UserWarning: not all nodes are included! are there nodes without edges?
#   warnings.warn("not all nodes are included! are there nodes without edges?")
# Epoch 1981/2000  ['loss:-30.198423385620117', 'val_loss:-29.97801971435547']]']
# loss: [-94.9290943145752, -72.11807060241699, -30.568882942199707]
# val loss: [188.81403350830078, -21.96747875213623, -30.336368083953857]
# Duration: 103.57323503494263

# %%
enron_folder = "data/enron/"
orchestrator = Orchestrator(enron_folder)
start = time.time()
res = orchestrator.lin_grid_search_flownet({"number_of_bijectors": [4, 6, 8]})
end = time.time()
print(f"Duration: {end-start}")
# Out:
# /Users/tonpoppe/workspace/tigger_adj_rep/tigger_adj/tigger_package/flownet.py:121: UserWarning: not all nodes are included! are there nodes without edges?
#   warnings.warn("not all nodes are included! are there nodes without edges?")
# Epoch 2981/3000  ['loss:-43.09165573120117', 'val_loss:-40.562496185302734']]]
# /Users/tonpoppe/workspace/tigger_adj_rep/tigger_adj/tigger_package/flownet.py:121: UserWarning: not all nodes are included! are there nodes without edges?
#   warnings.warn("not all nodes are included! are there nodes without edges?")
# Epoch 2981/3000  ['loss:-51.990047454833984', 'val_loss:-47.980369567871094']
# /Users/tonpoppe/workspace/tigger_adj_rep/tigger_adj/tigger_package/flownet.py:121: UserWarning: not all nodes are included! are there nodes without edges?
#   warnings.warn("not all nodes are included! are there nodes without edges?")
# Epoch 2981/3000  ['loss:-52.98154067993164', 'val_loss:-48.78642272949219']]]
# loss: [-43.235039710998535, -52.078264236450195, -53.068745613098145]
# val loss: [-40.690412521362305, -47.92945575714111, -48.84736347198486]
# Duration: 189.68677616119385

# %%
#final flow model
enron_folder = "data/enron/"
orchestrator = Orchestrator(enron_folder)
name, history = orchestrator.train_flow()
# Out:
# /Users/tonpoppe/workspace/tigger_adj_rep/tigger_adj/tigger_package/flownet.py:121: UserWarning: not all nodes are included! are there nodes without edges?
#   warnings.warn("not all nodes are included! are there nodes without edges?")
# Epoch 1101/3000  ['loss:-4.418868064880371', 'val_loss:-4.574000835418701']]']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/tonpoppe/workspace/tigger_adj_rep/tigger_adj/experiments/enron_synth_graph.ipynb Cell 17 line 4
#       <a href='vscode-notebook-cell:/Users/tonpoppe/workspace/tigger_adj_rep/tigger_adj/experiments/enron_synth_graph.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> enron_folder = "data/enron/"
#       <a href='vscode-notebook-cell:/Users/tonpoppe/workspace/tigger_adj_rep/tigger_adj/experiments/enron_synth_graph.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a> orchestrator = Orchestrator(enron_folder)
# ----> <a href='vscode-notebook-cell:/Users/tonpoppe/workspace/tigger_adj_rep/tigger_adj/experiments/enron_synth_graph.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a> name, history = orchestrator.train_flow()
#
# File ~/workspace/tigger_adj_rep/tigger_adj/tigger_package/orchestrator.py:41, in Orchestrator.train_flow(self)
#      37     embed = self.load_normalized_embed()
#      38     self.flownet = FlowNet(
#      39         config_path=self.config_path,
#      40         config_dict=self.config['flownet'])
# ---> 41     name, hist = self.flownet.train(embed, node)
#      42 return (name, hist)
#
# File ~/workspace/tigger_adj_rep/tigger_adj/tigger_package/flownet.py:101, in FlowNet.train(self, embed, node_attr)
#      98 if not self.model:
#      99     self.init_model()
# --> 101 history = self.train_model(x_data)
#     102 name = self.save_model()
#     104 if self.verbose >= 2:
#
# File ~/workspace/tigger_adj_rep/tigger_adj/tigger_package/flownet.py:78, in FlowNet.train_model(self, x_data)
#      70 # Display the loss every n_disp epoch
#      71 epoch_callback = LambdaCallback(
#      72     on_epoch_end=lambda cur_epoch, logs:
#      73         print(f'\rEpoch {cur_epoch+1}/{self.epoch}  {[str(k)+":"+str(v) for k,v in logs.items()]}', end="")
#      74         if cur_epoch % self.n_disp == 0 else False
#      75 )
# ---> 78 history = self.model.fit(x=x_data,
#      79                     y=np.zeros((ns, 0), dtype=np.float32),
#      80                     batch_size=batch_size,
#      81                     epochs=self.epoch,
#      82                     validation_split=0.2,
#      83                     shuffle=True,
#      84                     verbose=False,
#      85                     callbacks=[epoch_callback])
#      86 return history
#
# File ~/anaconda3/envs/tigger/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/tigger/lib/python3.11/site-packages/keras/src/engine/training.py:1832, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1816 if getattr(self, "_eval_data_handler", None) is None:
#    1817     self._eval_data_handler = data_adapter.get_data_handler(
#    1818         x=val_x,
#    1819         y=val_y,
#    (...)
#    1830         pss_evaluation_shards=self._pss_evaluation_shards,
#    1831     )
# -> 1832 val_logs = self.evaluate(
#    1833     x=val_x,
#    1834     y=val_y,
#    1835     sample_weight=val_sample_weight,
#    1836     batch_size=validation_batch_size or batch_size,
#    1837     steps=validation_steps,
#    1838     callbacks=callbacks,
#    1839     max_queue_size=max_queue_size,
#    1840     workers=workers,
#    1841     use_multiprocessing=use_multiprocessing,
#    1842     return_dict=True,
#    1843     _use_cached_eval_dataset=True,
#    1844 )
#    1845 val_logs = {
#    1846     "val_" + name: val for name, val in val_logs.items()
#    1847 }
#    1848 epoch_logs.update(val_logs)
#
# File ~/anaconda3/envs/tigger/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/tigger/lib/python3.11/site-packages/keras/src/engine/training.py:2261, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2259 if self.enable_tune_steps_per_execution:
#    2260     self._steps_per_execution_tuner.start()
# -> 2261 for (
#    2262     _,
#    2263     dataset_or_iterator,
#    2264 ) in data_handler.enumerate_epochs():  # Single epoch.
#    2265     self.reset_metrics()
#    2266     with data_handler.catch_stop_iteration():
#
# File ~/anaconda3/envs/tigger/lib/python3.11/site-packages/keras/src/engine/data_adapter.py:1341, in DataHandler.enumerate_epochs(self)
#    1339 """Yields `(epoch, tf.data.Iterator)`."""
#    1340 with self._truncate_execution_to_epoch():
# -> 1341     data_iterator = iter(self._dataset)
#    1342     for epoch in range(self._initial_epoch, self._epochs):
#    1343         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# File ~/anaconda3/envs/tigger/lib/python3.11/site-packages/tensorflow/python/data/ops/dataset_ops.py:496, in DatasetV2.__iter__(self)
#     494 if context.executing_eagerly() or ops.inside_function():
#     495   with ops.colocate_with(self._variant_tensor):
# --> 496     return iterator_ops.OwnedIterator(self)
#     497 else:
#     498   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     499                      "iteration in eager mode or within tf.function.")
#
# File ~/anaconda3/envs/tigger/lib/python3.11/site-packages/tensorflow/python/data/ops/iterator_ops.py:705, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     701   if (components is not None or element_spec is not None):
#     702     raise ValueError(
#     703         "When `dataset` is provided, `element_spec` and `components` must "
#     704         "not be specified.")
# --> 705   self._create_iterator(dataset)
#     707 self._get_next_call_count = 0
#
# File ~/anaconda3/envs/tigger/lib/python3.11/site-packages/tensorflow/python/data/ops/iterator_ops.py:744, in OwnedIterator._create_iterator(self, dataset)
#     741   assert len(fulltype.args[0].args[0].args) == len(
#     742       self._flat_output_types)
#     743   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 744 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File ~/anaconda3/envs/tigger/lib/python3.11/site-packages/tensorflow/python/ops/gen_dataset_ops.py:3420, in make_iterator(dataset, iterator, name)
#    3418 if tld.is_eager:
#    3419   try:
# -> 3420     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3421       _ctx, "MakeIterator", name, dataset, iterator)
#    3422     return _result
#    3423   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# save results
import pickle
train_config = orchestrator.config.copy()
train_config['metrics'] = history.history
res_filename = 'data/enron/exp_results/flownet_final_run_metrics.pickle'
pickle.dump(train_config, open(res_filename, 'wb'))

# %%
# convert final embedding to csv for tensorflow embedding viewer
import pandas as pd
filepath = orchestrator.config_path + orchestrator.config['flownet']['flownet_config_path']
obj = pickle.load(open(filepath + name, 'rb'))
pickle.dump(obj,open(filepath + "flowmodel_final.pickle", 'wb'))

# %% [markdown]
# ## sample flownet

# %%
# Sample flow net
enron_folder = "data/enron/"
orchestrator = Orchestrator(enron_folder)
model_name = "flowmodel_final.pickle"
orchestrator.sample_flownet()

# %%
# convert final embedding to csv for tensorflow embedding viewer
import pandas as pd
embed = pd.read_parquet('data/enron/synth_nodes.parquet')
embed.to_parquet('data/enron/synth_nodes_final.parquet')
embed.to_csv("data/enron/synth_nodes_files.csv", sep='\t', header=False, index=False, )

# %%
enron_folder = "data/enron/"
orchestrator = Orchestrator(enron_folder)
orig_node = orchestrator._load_nodes()
orig_embed = orchestrator.load_normalized_embed()
x_data = orig_embed.join(orig_node, how='inner')

# %%
# plot samples embedding
import matplotlib.pyplot as plt
import math
fig = plt.figure(figsize=(20,20))
dim = embed.shape[1]
for i in range(dim):
    ax = fig.add_subplot(math.ceil(dim/2),2, i+1)
    ax.hist(embed.loc[:, i], bins=20, alpha=0.5, color='g', label='flow')
    ax.hist(x_data.iloc[:, i], bins=20, alpha=0.5, color='r', label='orig')

plt.legend()
plt.show()

# %% [markdown]
# ## train lstm

# %%
enron_folder = "data/enron/"
orchestrator = Orchestrator(enron_folder)
# res = orchestrator.lin_grid_search_lstm({'lr': [0.001, 0.0005, 0.0001]})
loss_dict = orchestrator.train_lstm()
# loss=3.529276132583618, val_loss: 3.1
#
# Out:
# /Users/tonpoppe/workspace/tigger_adj_rep/tigger_adj/tigger_package/inductive_controller.py:232: UserWarning: feat df has 150 rows and vocab has 151 instead of 152. This can be cause by unconnected nodes.
#   warnings.warn(f"feat df has {nodes.shape[0]} rows and vocab has {node_attr.shape[0]} instead of {nodes.shape[0] + 2}. This can be cause by unconnected nodes.")
# /Users/tonpoppe/anaconda3/envs/tigger/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#   0%|          | 0/2689 [00:00<?, ?it/s]
# Number of components, 14
# /Users/tonpoppe/anaconda3/envs/tigger/lib/python3.11/site-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
#   0%|          | 0/3000 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  2950 / 3000, epoch:399 loss=3.03436017036438, val_loss: 3.904753446578979595

# %%
loss_dict['val_dict'].keys()
# Out:
# dict_keys(['loss', 'elbo_loss', 'kl_loss', 'reconstruction_ne', 'reconstruction_edge', 'cross_entropy_cluster', 'reconstruction_feat'])

# %%
import matplotlib.pyplot as plt
metric = 'reconstruction_edge'
plt.plot(loss_dict[metric], label='metric')
plt.plot(loss_dict['val_dict'][metric], label='val_metric')
# plt.plot(loss_dict['val_dict']['loss'], label='val_loss')
plt.legend()
plt.show()

# %%
# create synthetic walks
# loss_dict = orchestrator.train_lstm()
orchestrator.create_synthetic_walks(target_cnt=3000, map_real_time=False)

# %%
# convert final embedding to csv for tensorflow embedding viewer
import pickle
obj = pickle.load(open('data/enron/synth_walks.pickle', 'rb'))
pickle.dump(obj, open('data/enron/synth_walks_final.pickle', 'wb'))

# %% [markdown]
# ## create synthetic graph

# %%
enron_folder = "data/enron/"
orchestrator = Orchestrator(enron_folder)
orchestrator.generate_synth_graph()
# Out:
# /Users/tonpoppe/workspace/tigger_adj_rep/tigger_adj/tigger_package/inductive_controller.py:232: UserWarning: feat df has 150 rows and vocab has 151 instead of 152. This can be cause by unconnected nodes.
#   warnings.warn(f"feat df has {nodes.shape[0]} rows and vocab has {node_attr.shape[0]} instead of {nodes.shape[0] + 2}. This can be cause by unconnected nodes.")
# /Users/tonpoppe/anaconda3/envs/tigger/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#   0%|          | 0/2689 [00:00<?, ?it/s]
# /Users/tonpoppe/anaconda3/envs/tigger/lib/python3.11/site-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Number of components, 14

# %%
import pandas as pd
embed = pd.read_parquet('data/enron/synth_graph/node_attributes.parquet')
embed.to_parquet('data/enron/synth_graph/node_attributes_final.parquet')
embed = pd.read_parquet('data/enron/synth_graph/adjacency.parquet')
embed.to_parquet('data/enron/synth_graph/adjacency_final.parquet')
